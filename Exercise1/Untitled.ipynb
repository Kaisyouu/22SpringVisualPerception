# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('car.jpg')
plt.imshow(image)
plt.show()

# %%
A = np.array([[1, 2, 3, 4], [5, 2, 1, 2], [5, 2, 2, 8], [3, 7, 10, 21]])
B = np.array([2980, 3700, 5440, 11960])
X = np.linalg.solve(A, B)
print(X)
# Out:
# [400. 500. 180. 260.]

# %%
gang = image[400:500, 180:260]
plt.imshow(gang)
plt.show()

# %%
h, w = gang.shape[0], gang.shape[1]
gang2 = cv2.resize(gang, None, fx=2, fy=2, interpolation = cv2.INTER_CUBIC)
plt.imshow(gang2)
plt.show()

# %%
gray = cv2.cvtColor(gang, cv2.COLOR_RGB2GRAY)
gray.shape
plt.imshow(gray, cmap='gray')

# %%
w, h = image.shape[0], image.shape[1]
print(w, h)
# Out:
# 497 699

# %%
r = cv2.selectROI(image)
